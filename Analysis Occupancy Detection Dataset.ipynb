# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ganjar87/data_science_practice/main/datatraining.txt')
data
# Out:
#                      date  Temperature  ...  HumidityRatio  Occupancy
# 1     2015-02-04 17:51:00        23.18  ...       0.004793          1
# 2     2015-02-04 17:51:59        23.15  ...       0.004783          1
# 3     2015-02-04 17:53:00        23.15  ...       0.004779          1
# 4     2015-02-04 17:54:00        23.15  ...       0.004772          1
# 5     2015-02-04 17:55:00        23.10  ...       0.004757          1
# ...                   ...          ...  ...            ...        ...
# 8139  2015-02-10 09:29:00        21.05  ...       0.005579          1
# 8140  2015-02-10 09:29:59        21.05  ...       0.005563          1
# 8141  2015-02-10 09:30:59        21.10  ...       0.005596          1
# 8142  2015-02-10 09:32:00        21.10  ...       0.005621          1
# 8143  2015-02-10 09:33:00        21.10  ...       0.005612          1
#
# [8143 rows x 7 columns]

# %% [markdown]
# #Probability Mass Function

# %%
# Probability Mass Function

from scipy.stats import norm

sns.histplot(data=data, x='Occupancy',stat="probability")      
plt.xticks(rotation='45')                                  
plt.show()

# %%
data['Occupancy'].value_counts(normalize = True)
# Out:
# 0    0.78767
# 1    0.21233
# Name: Occupancy, dtype: float64

# %% [markdown]
# #Analisis Distribusi

# %%
# DataFrame untuk Occupancy = 0
occupancy_0 = data[data['Occupancy']==0]
occupancy_0.head()
# Out:
#                    date  Temperature  Humidity  ...    CO2  HumidityRatio  Occupancy
# 17  2015-02-04 18:07:00       23.000     27.20  ...  681.5       0.004728          0
# 18  2015-02-04 18:08:00       22.945     27.29  ...  685.0       0.004728          0
# 19  2015-02-04 18:08:59       22.945     27.39  ...  685.0       0.004745          0
# 20  2015-02-04 18:10:00       22.890     27.39  ...  689.0       0.004730          0
# 21  2015-02-04 18:10:59       22.890     27.39  ...  689.5       0.004730          0
#
# [5 rows x 7 columns]

# %%
# DataFrame untuk Occupancy = 1
occupancy_1 = data[data['Occupancy']==1]
occupancy_1.head()
# Out:
#                   date  Temperature  Humidity  ...     CO2  HumidityRatio  Occupancy
# 1  2015-02-04 17:51:00        23.18   27.2720  ...  721.25       0.004793          1
# 2  2015-02-04 17:51:59        23.15   27.2675  ...  714.00       0.004783          1
# 3  2015-02-04 17:53:00        23.15   27.2450  ...  713.50       0.004779          1
# 4  2015-02-04 17:54:00        23.15   27.2000  ...  708.25       0.004772          1
# 5  2015-02-04 17:55:00        23.10   27.2000  ...  704.50       0.004757          1
#
# [5 rows x 7 columns]

# %%
# Distribusi Temperature saat Occupancy = 0
min = occupancy_0['Temperature'].min()
max = occupancy_0['Temperature'].max()

mean = occupancy_0['Temperature'].mean()
std = occupancy_0['Temperature'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_0, x='Temperature',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
# Distribusi Temperature saat Occupancy = 1
min = occupancy_1['Temperature'].min()
max = occupancy_1['Temperature'].max()

mean = occupancy_1['Temperature'].mean()
std = occupancy_1['Temperature'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_1, x='Temperature',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
sns.histplot(data=data, x='Temperature', hue='Occupancy')     
plt.xticks(rotation='45')                                  
plt.show()

# %% [markdown]
# Penjelasan : terdapat perbedaan Distribusi Temperature saat Occupancy = 1 dan saat Occupancy = 0. Dapat dilihat pada histogram di atas, saat Occupancy = 1 Suhu cenderung meningkat dikisaran 21-23 derajat. Sedangkan saat Occupancy = 0 suhu lebih banyak berada dikisaran 19-21 derajat. Hal ini menunjukkan bahwa saat tidak berpenghuni, suhu akan menjadi lebih dingin. Akan tetapi, Keduanya memiliki kemiripan pada garis Probability Density Function yang ditampilkan.

# %%
# Distribusi Humidity saat Occupancy = 0
min = occupancy_0['Humidity'].min()
max = occupancy_0['Humidity'].max()

mean = occupancy_0['Humidity'].mean()
std = occupancy_0['Humidity'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_0, x='Humidity',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
# Distribusi Humidity saat Occupancy = 1
min = occupancy_1['Humidity'].min()
max = occupancy_1['Humidity'].max()

mean = occupancy_1['Humidity'].mean()
std = occupancy_1['Humidity'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_1, x='Humidity',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
sns.histplot(data=data, x='Humidity', hue='Occupancy')     
plt.xticks(rotation='45')                                  
plt.show()

# %% [markdown]
# Penjelasan : Setelah mengamati perbedaan data Distribusi Humidity pada saat Occupancy = 1 dan pada saat Occupancy = 0 dapat ditarik kesimpulan bahwa terdapat perbedaan antara keduanya. Kelembaban mengalami peningkatan ketika keadaan berpenghuni menurun dan mengalami penurunan ketika terjadi kenaikan jumlah penghuni. Akan tetapi, Keduanya memiliki kemiripan pada garis Probability Density Function yang ditampilkan.

# %%
# Distribusi Light saat Occupancy = 0
min = occupancy_0['Light'].min()
max = occupancy_0['Light'].max()

mean = occupancy_0['Light'].mean()
std = occupancy_0['Light'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_0, x='Light',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
# Distribusi Light saat Occupancy = 1
min = occupancy_1['Light'].min()
max = occupancy_1['Light'].max()

mean = occupancy_1['Light'].mean()
std = occupancy_1['Light'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_1, x='Light',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
sns.histplot(data=data, x='Light', hue='Occupancy')     
plt.xticks(rotation='45')                                  
plt.show()

# %% [markdown]
# Penjelasan : Setelah mengamati perbedaan data Distribusi Light pada saat Occupancy = 1 dan pada saat Occupancy = 0 dapat ditarik kesimpulan bahwa terdapat perbedaan antara keduanya. Saat dalam keadaan tidak berpenghuni penggunaan Lampu berada di angka 0 sebagai angka tertingginya, sedangkan pada saat dalam keadaan berpenghuni penggunaan lampu berada di kisaran lebih dari 400 dan tidak lebih dari 600 sebagai angka tertingginya.

# %%
# Distribusi CO2 saat Occupancy = 0
min = occupancy_0['CO2'].min()
max = occupancy_0['CO2'].max()

mean = occupancy_0['CO2'].mean()
std = occupancy_0['CO2'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_0, x='CO2',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
# Distribusi  CO2 saat Occupancy = 1
min = occupancy_1['CO2'].min()
max = occupancy_1['CO2'].max()

mean = occupancy_1['CO2'].mean()
std = occupancy_1['CO2'].std()


x_pdf = np.linspace(min, max)
y_pdf = norm.pdf(x_pdf, mean, std)

sns.histplot(data=occupancy_1, x='CO2',stat="density")
plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')       
plt.legend()                                            
plt.show()

# %%
sns.histplot(data=data, x='CO2', hue='Occupancy')     
plt.xticks(rotation='45')                                  
plt.show()

# %% [markdown]
# Penjelasan : Setelah mengamati perbedaan data Distribusi CO2 pada saat Occupancy = 1 dan pada saat Occupancy = 0 dapat ditarik kesimpulan bahwa terdapat perbedaan antara keduanya. Ketika dalam keadaan tidak berpenghuni, CO2 berada di kisaran 400 sampai 600 dan menunjukkan keadaan Right Skewed. Sedangkan ketika dalam keadaan berpenghuni, CO2 memiliki angka tertinggi di 800 dan menunjukkan keadaan Right Skewed.

# %% [markdown]
# #Kolerasi Untuk Semua Attributes

# %%
data.corr()
# Out:
#                Temperature  Humidity  ...  HumidityRatio  Occupancy
# Temperature       1.000000 -0.141759  ...       0.151762   0.538220
# Humidity         -0.141759  1.000000  ...       0.955198   0.132964
# Light             0.649942  0.037828  ...       0.230420   0.907352
# CO2               0.559894  0.439023  ...       0.626556   0.712235
# HumidityRatio     0.151762  0.955198  ...       1.000000   0.300282
# Occupancy         0.538220  0.132964  ...       0.300282   1.000000
#
# [6 rows x 6 columns]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(), annot=True, )
plt.title("Heatmap Correlation", fontsize = 25);
plt.show()

# %% [markdown]
# - **Variable dengan Positif Korelasi**
# 1. Temperature dan Light (lemah)
# 2. Temperature dan CO2 (lemah)
# 3. Temperature dan Occupancy (Lemah)
# 4. Humidity dan CO2 (Lemah)
# 5. Humidity dan Humidity Ratio (kuat)
# 6. Humidity dan occupany (lemah)
# 7. Light dan CO2 (lemah)
# 8. Light dan Humidity Ratio (lemah)
# 9. Light dan Occupancy (kuat)
# 10. CO2 dan Humidity Ratio (lemah)
# 11. CO2 dan Occupancy (Cukup Kuat)
# 12. Humidity Ratio dan Temperature (lemah)
# 13. Humidity Ratio dan Occupancy (lemah)
#
# - **Variable dengan Negatif Korelasi**
# 1. Temperature dan Humidity (lemah)
#
# - **Variable yang tidak memiliki Korelasi**
# 1. Humidity dan Light

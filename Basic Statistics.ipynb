# %%
import pandas as pd

# %%
data = pd.read_csv ('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
data
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
data[['price', 'bedrooms', 'bathrooms']].describe()
# Out:
#               price      bedrooms     bathrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757
# std    3.671272e+05      0.930062      0.770163
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000
# 50%    4.500000e+05      3.000000      2.250000
# 75%    6.450000e+05      4.000000      2.500000
# max    7.700000e+06     33.000000      8.000000

# %%
data[['price', 'bedrooms', 'bathrooms']].mean()
# Out:
# price        540088.141767
# bedrooms          3.370842
# bathrooms         2.114757
# dtype: float64

# %%
data[['price', 'bedrooms', 'bathrooms']].mode()
# Out:
#       price  bedrooms  bathrooms
# 0  350000.0       3.0        2.5
# 1  450000.0       NaN        NaN

# %%
print(data[['price', 'bedrooms', 'bathrooms']].skew())
# Out:
# price        4.024069
# bedrooms     1.974300
# bathrooms    0.511108
# dtype: float64

# %%
data['price'].plot.density()

# %%
data['bedrooms'].plot.density()

# %%
data['bathrooms'].plot.density()

# %% [markdown]
# #Interpretation

# %% [markdown]
# - Berdasarkan Variable "Price" menunjukkan bahwa:
#     1. Distribution <br>
#     Pada variable "price" dapat diketahui bahwa nilai yang sering muncul adalah 350000
#     2. Central Tendency <br>
#     Pada variable "Price" menghasilkan nilai Central Tendecy sebagai berikut: <br>
#     a. Nilai Rata-rata variable tersebut adalah 540088.141767<br>
#     b. Nilai Median variable tersebut adalah 4.500000 <br>
#     c. Nilai Modus variable tersebut adalah 350000 <br>
#     3. Variability <br>
#     Pada variable "Price" menghasilkan nilai Variability sebagai berikut: <br>
#     a. Standard Deviation pada variable "Price" memiliki nilai 3.671272 <br>
#     b. Minimum and maximum values pada variable "Price" adalah 7.5 dan 7.7 <br>
#     c. Skewness pada variable "Price" dapat diinterpretasikan sebagai Highly skewed distribution karena nilainya 4.024069. <br>
#
# - Berdasarkan Variable "Bedrooms" menunjukkan bahwa:
#     1. Distribution <br>
#     Pada variable "Bedrooms" dapat diketahui bahwa nilai yang sering muncul adalah 3
#     2. Central Tendency <br>
#     Pada variable "Bedrooms" menghasilkan nilai Central Tendecy sebagai berikut: <br>
#     a. Nilai Rata-rata variable tersebut adalah 3.370842<br>
#     b. Nilai Median variable tersebut adalah 3 <br>
#     c. Nilai Modus variable tersebut adalah 3 <br>
#     3. Variability <br>
#     Pada variable "Bedrooms" menghasilkan nilai Variability sebagai berikut: <br>
#     a. Standard Deviation pada variable "Bedrooms" memiliki nilai 0.930062 <br>
#     b. Minimum and maximum values pada variable "Bedrooms" adalah 0 dan 33 <br>
#     c. Skewness pada variable "Bedrooms" dapat diinterpretasikan sebagai Highly skewed distribution karena nilainya 1.974300. <br>
#
# - Berdasarkan Variable "Bathrooms" menunjukkan bahwa:
#     1. Distribution <br>
#     Pada variable "Bathrooms" dapat diketahui bahwa nilai yang sering muncul adalah 2.5
#     2. Central Tendency <br>
#     Pada variable "Bathrooms" menghasilkan nilai Central Tendecy sebagai berikut: <br>
#     a. Nilai Rata-rata variable tersebut adalah 2.114757 <br>
#     b. Nilai Median variable tersebut adalah 2.25 <br>
#     c. Nilai Modus variable tersebut adalah 2.5 <br>
#     3. Variability <br>
#     Pada variable "Bathrooms" menghasilkan nilai Variability sebagai berikut: <br>
#     a. Standard Deviation pada variable "Bathrooms" memiliki nilai 0.770163 <br>
#     b. Minimum and maximum values pada variable "Bathrooms" adalah 0 dan 8 <br>
#     c. Skewness pada variable "Bathrooms" dapat diinterpretasikan sebagai Approximately symmetric distribution karena nilainya 0.511108. <br>

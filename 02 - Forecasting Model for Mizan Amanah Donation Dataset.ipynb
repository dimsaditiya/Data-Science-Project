# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt , seaborn as sns
from scipy.stats import norm

# %% [markdown]
# #Read Dataset

# %% [markdown]
# ##Dataset Guest

# %% [markdown]
# ### Donasi

# %%
donasig1 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Januari-donasi-guest.csv')
donasig2 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Februari-donasi-guest.csv')
donasig3 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Maret-donasi-guest.csv')
donasig4 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/April-donasi-guest.csv')
donasig5 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Mei-donasi-guest.csv')
donasig6 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Juni-donasi-guest.csv')
donasig7 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Juli-donasi-guest.csv')
donasig8 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Agustus-donasi-guest.csv')
donasig9 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/September-donasi-guest.csv')
donasig10 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Oktober-donasi-guest.csv')
donasig11 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/November-donasi-guest.csv')
donasig12 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Donasi/Desember-donasi-guest.csv')

# %% [markdown]
# #### Combine

# %%
donasig = pd.concat([donasig1,donasig2,donasig3,donasig4,donasig5,donasig6,donasig7,donasig8,donasig9,donasig10,donasig11,donasig12])
donasig
# Out:
#         ID  ...                      metode_pembayaran
# 0    27022  ...                                  gopay
# 1    27045  ...  Transfer Bank Mandiri - 1320505050535
# 2    27055  ...                          bank_transfer
# 3    27061  ...  Transfer Bank Mandiri - 1320505050535
# 4    27083  ...                          bank_transfer
# ..     ...  ...                                    ...
# 127  43371  ...                                  gopay
# 128  43372  ...                                  gopay
# 129  43373  ...                                MANDIRI
# 130  43374  ...                          bank_transfer
# 131  43378  ...                                  gopay
#
# [2873 rows x 8 columns]

# %% [markdown]
# ### Zakat

# %%
zakatg = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Guest/Zakat/Januari-sampai-desember-zakat-guest.csv')

# %% [markdown]
# ##Show dataset

# %%
donasig
# Out:
#         ID  ...                      metode_pembayaran
# 0    27022  ...                                  gopay
# 1    27045  ...  Transfer Bank Mandiri - 1320505050535
# 2    27055  ...                          bank_transfer
# 3    27061  ...  Transfer Bank Mandiri - 1320505050535
# 4    27083  ...                          bank_transfer
# ..     ...  ...                                    ...
# 127  43371  ...                                  gopay
# 128  43372  ...                                  gopay
# 129  43373  ...                                MANDIRI
# 130  43374  ...                          bank_transfer
# 131  43378  ...                                  gopay
#
# [2873 rows x 8 columns]

# %%
zakatg
# Out:
#        ID                nama_lengkap  ...      status metode_pembayaran
# 0    2702  Muhammad Ramadhan Alkausar  ...  settlement             gopay
# 1    2704         Muhamad Haris Yahya  ...  settlement     bank_transfer
# 2    2710       Karunia Erldi Abraham  ...  settlement     bank_transfer
# 3    2718                Irma Suryati  ...  settlement          echannel
# 4    2739     Arriman Maulana Makmoen  ...  settlement     bank_transfer
# ..    ...                         ...  ...         ...               ...
# 333  4019           Fraskatia Syahrin  ...  settlement           MANDIRI
# 334  4028       Dinar Swastika Ardias  ...  settlement     bank_transfer
# 335  4029                 Hamba Allah  ...  settlement     bank_transfer
# 336  4030                 Hamba Allah  ...  settlement     bank_transfer
# 337  4033                       ninis  ...  settlement           MANDIRI
#
# [338 rows x 8 columns]

# %% [markdown]
# ## Guest Cleaning

# %%
#Check Duplicated Data
print(donasig.duplicated().sum())
# Out:
# 0

# %%
donasig.describe()
# Out:
#                  ID  total_donasi
# count   2873.000000  2.873000e+03
# mean   36470.638705  2.364189e+05
# std     4615.058652  6.531753e+05
# min    27022.000000  7.500000e+02
# 25%    32734.000000  3.000000e+04
# 50%    36402.000000  1.000000e+05
# 75%    40556.000000  2.000000e+05
# max    43378.000000  2.000063e+07

# %%
#Mencari Variable yang memiliki missing value
donasig.isnull().sum()
# Out:
# ID                    0
# nama_lengkap         12
# platform              4
# judul                 0
# tanggal               0
# total_donasi          0
# status                0
# metode_pembayaran     0
# dtype: int64

# %% [markdown]
# ## Dataset Users

# %% [markdown]
# ### Donasi

# %%
donasiu1 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Januari-donasi-users.csv')
donasiu2 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Februari-donasi-users.csv')
donasiu3 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Maret-donasi-users.csv')
donasiu4 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/April-donasi-users.csv')
donasiu5 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Mei-donasi-users.csv')
donasiu6 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Juni-donasi-users.csv')
donasiu7 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Juli-donasi-users.csv')
donasiu8 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Agustus-donasi-users.csv')
donasiu9 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/September-donasi-users.csv')
donasiu10 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Oktober-donasi-users.csv')
donasiu11 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/November-donasi-users.csv')
donasiu12 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Donasi/Desember-donasi-users.csv')

# %% [markdown]
# ####Combine Dataset

# %%
donasiu = pd.concat([donasiu1,donasiu2,donasiu3,donasiu4,donasiu5,donasiu6,donasiu7,donasiu8,donasiu9,donasiu10,donasiu11,donasiu12])
donasiu
# Out:
#         ID  ...                      metode_pembayaran
# 0    26790  ...                          bank_transfer
# 1    26791  ...                               echannel
# 2    26792  ...                          bank_transfer
# 3    26793  ...  Transfer Bank Mandiri - 1320505050535
# 4    26794  ...                                LINKAJA
# ..     ...  ...                                    ...
# 128  43379  ...                Mandiri - 1320006531140
# 129  43380  ...                Mandiri - 1320006531140
# 130  43381  ...                       BCA - 1393004952
# 131  43382  ...           Mandiri Syariah - 7277777775
# 132  43384  ...                                MANDIRI
#
# [6208 rows x 8 columns]

# %% [markdown]
# ### Zakat

# %%
zakatu1 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Januari-zakat-users.csv')
zakatu2 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Februari-zakat-users.csv')
zakatu3 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Maret-zakat-users.csv')
zakatu4 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/April-zakat-users.csv')
zakatu5 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Mei-zakat-users.csv')
zakatu6 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Juni-zakat-users.csv')
zakatu7 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Juli-zakat-users.csv')
zakatu8 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Agustus-zakat-users.csv')
zakatu9 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/September-zakat-users.csv')
zakatu10 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Oktober-zakat-users.csv')
zakatu11 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/November-zakat-users.csv')
zakatu12 = pd.read_csv('https://raw.githubusercontent.com/dimsaditiya/Project-Machine-Learning-Forecasting/main/Online%20Donation/Users/Zakat/Desember-zakat-users.csv')

# %%
zakatu = pd.concat([zakatu1,zakatu2,zakatu3,zakatu4,zakatu5,zakatu6,zakatu7,zakatu8,zakatu9,zakatu10,zakatu11,zakatu12])
zakatu
# Out:
#       ID                        name  ...      status        metode_pembayaran
# 0   2689  Dirga Imam Gozali Sumantri  ...  settlement                 echannel
# 1   2690    Putu Berly Calvina Izumi  ...  settlement            bank_transfer
# 2   2691          Pak Saeful Rokhman  ...  settlement         BCA - 1393004952
# 3   2692    Vinanda Langgeng Kencana  ...  settlement         BCA - 1393040002
# 4   2693                      Novias  ...  settlement         BCA - 1393040002
# ..   ...                         ...  ...         ...                      ...
# 7   4031                 Fara Kirana  ...  settlement         BCA - 1393004952
# 8   4032   Libonit Poetry Mayangsari  ...  settlement         BCA - 1393040002
# 9   4034              Nike Pudjiwati  ...  settlement         BCA - 1393040002
# 10  4035               Helena Shinta  ...  settlement  Mandiri - 1010012312318
# 11  4036               Ima Gusnandar  ...  settlement  Mandiri - 1320006531140
#
# [337 rows x 8 columns]

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Guest

# %%
#Mencari Variable yang memiliki missing value
donasig.isnull().sum()
# Out:
# ID                    0
# nama_lengkap         12
# platform              4
# judul                 0
# tanggal               0
# total_donasi          0
# status                0
# metode_pembayaran     0
# dtype: int64

# %%
donasig["metode_pembayaran"].replace(["gopay", "OVO", "echannel","DANA","LINKAJA"],"emoney", inplace=True)
donasig["metode_pembayaran"].replace(["Transfer Bank Mandiri - 1320505050535","Transfer Bank Mandiri Syariah - 7277777775","MANDIRI","BRI","BNI","PERMATA","bni_va","Transfer Bank BCA Gani - 2332438027","credit_card"],"bank_transfer",inplace=True)
donasig["status"].replace(["COMPLETED", "SUCCESS_COMPLETED", "PAID"],"settlement", inplace=True)
donasig["nama_lengkap"].fillna("Seseorang", inplace = True)
donasig["platform"].fillna("Unknown", inplace = True)
donasig["platform"].replace("WEB", "Web",inplace = True)
donasig['nama_lengkap'] = donasig['nama_lengkap'].str.lower()
donasig['judul'] = donasig['judul'].str.lower()
donasig["total_donasi"] = pd.to_numeric(donasig["total_donasi"])
donasig
# Out:
#         ID        nama_lengkap  ...      status metode_pembayaran
# 0    27022    putu darma putra  ...  settlement            emoney
# 1    27045         hamba allah  ...  settlement     bank_transfer
# 2    27055         evi wirawan  ...  settlement     bank_transfer
# 3    27061             achmadi  ...  settlement     bank_transfer
# 4    27083          lia soraya  ...  settlement     bank_transfer
# ..     ...                 ...  ...         ...               ...
# 127  43371            prajitno  ...  settlement            emoney
# 128  43372                yudi  ...  settlement            emoney
# 129  43373              taufik  ...  settlement     bank_transfer
# 130  43374  fajar sovin namiya  ...  settlement     bank_transfer
# 131  43378  mawaddah khairiyah  ...  settlement            emoney
#
# [2873 rows x 8 columns]

# %%
donasig[donasig['nama_lengkap'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, nama_lengkap, platform, judul, tanggal, total_donasi, status, metode_pembayaran]
# Index: []

# %%
donasig.to_csv('donasig.csv')

# %%
donasig.describe()
# Out:
#                  ID  total_donasi
# count   2873.000000  2.873000e+03
# mean   36470.638705  2.364189e+05
# std     4615.058652  6.531753e+05
# min    27022.000000  7.500000e+02
# 25%    32734.000000  3.000000e+04
# 50%    36402.000000  1.000000e+05
# 75%    40556.000000  2.000000e+05
# max    43378.000000  2.000063e+07

# %%
donasig['total_donasi'].sum(axis = 0,skipna = True )
# Out:
# 679231448.0

# %%
#Mencari Variable yang memiliki missing value
zakatg.isnull().sum()
# Out:
# ID                   0
# nama_lengkap         0
# platform             0
# category             0
# tanggal              0
# total_zakat          0
# status               0
# metode_pembayaran    0
# dtype: int64

# %%
zakatg["metode_pembayaran"].replace(["gopay", "OVO", "echannel","DANA","LINKAJA"],"emoney", inplace=True)
zakatg["metode_pembayaran"].replace(["MANDIRI","BRI","BNI","Transfer Bank Mandiri - 1320505050519","Transfer Bank Mandiri Syariah - 7273737377","PERMATA","credit_card"],"bank_transfer",inplace=True)
zakatg["platform"].replace("WEB", "Web",inplace = True)
zakatg['nama_lengkap'] = zakatg['nama_lengkap'].str.lower()
zakatg["total_zakat"] = pd.to_numeric(zakatg["total_zakat"])
zakatg.head()
# Out:
#      ID                nama_lengkap  ...      status metode_pembayaran
# 0  2702  muhammad ramadhan alkausar  ...  settlement            emoney
# 1  2704         muhamad haris yahya  ...  settlement     bank_transfer
# 2  2710       karunia erldi abraham  ...  settlement     bank_transfer
# 3  2718                irma suryati  ...  settlement            emoney
# 4  2739     arriman maulana makmoen  ...  settlement     bank_transfer
#
# [5 rows x 8 columns]

# %%
zakatg.to_csv('donasig.csv')

# %%
zakatg.describe()
# Out:
#                 ID   total_zakat
# count   338.000000  3.380000e+02
# mean   3407.393491  2.960036e+05
# std     275.155002  9.613494e+05
# min    2702.000000  1.000000e+04
# 25%    3201.250000  4.000000e+04
# 50%    3413.500000  7.000000e+04
# 75%    3585.750000  2.000000e+05
# max    4033.000000  1.000000e+07

# %%
zakatg['total_zakat'].sum(axis = 0,skipna = True )
# Out:
# 100049228.0

# %% [markdown]
# ###Users

# %%
#Mencari Variable yang memiliki missing value
donasiu.isnull().sum()
# Out:
# ID                   0
# name                 2
# platform             0
# judul                0
# tanggal              0
# total_donasi         0
# status               0
# metode_pembayaran    0
# dtype: int64

# %%
donasiu[donasiu['name'].isna()]
# Out:
#         ID name    platform  ... total_donasi      status  metode_pembayaran
# 133  39774  NaN  Web Mobile  ...      25000.0  settlement      bank_transfer
# 14   41621  NaN      CFD v2  ...      50000.0  settlement      bank_transfer
#
# [2 rows x 8 columns]

# %%
donasiu.to_csv('donasiu.csv')

# %%
donasiu["metode_pembayaran"].replace(["SHOPEEPAY","akulaku","gopay", "OVO", "echannel","DANA","LINKAJA"],"emoney", inplace=True)
donasiu["metode_pembayaran"].replace(["Transfer Bank Mandiri - 1320505050535","Mandiri - 1320006531140","Transfer Bank Mandiri Syariah - 7277777775","Mandiri Syariah - 7277777775","MANDIRI","BRI","BNI","PERMATA","bni_va","BCA - 1393004952","BCA - 1393000001","BCA - 1393040002","BCA - 1393040100","BNI - 0152010118","BNI - 152010118","BNI - 4714715556","BNI Mizan Amanah","BNI Syariah - 5455440006","BNI Yayasan Mizan Amanah","BRI - 013701000379303","BNI Syariah Yayasan Mizan Amanah","BRI Yayasan Mizan Amanah","Muamalat Yayasan Mizan Amanah","Muamalat - 4080300000","Muamalat - 4080200000","Muamalat - 4080400000","BRI - 009601003148309","Mandiri Syariah - 7273737377","Mandiri - 1320040401144","Mandiri - 1640001852625","Mandiri - 1640002651117","Mandiri - 1490010260646","Mandiri - 1320505050519","Mandiri - 1320505050535","Mandiri - 1320505050527","Mandiri - 1010011122221","Mandiri - 1320020040060","Mandiri - 1010012312318","Mandiri - 1280006235151","Mandiri Syariah - 7275757572","credit_card","Mandiri Syariah Yayasan Mizan Amanah","Mandiri Yayasan Mizan Amanah" ,"BCA Yayasan Mizan Amanah","bca_va"],"bank_transfer",inplace=True)
donasiu["status"].replace(["COMPLETED", "SUCCESS_COMPLETED", "PAID"],"settlement", inplace=True)
donasiu["platform"].replace("WEB", "Web",inplace = True)
donasiu['name'] = donasiu['name'].str.lower()
donasiu['judul'] = donasiu['judul'].str.lower()
donasiu["name"].fillna("Seseorang", inplace = True)
donasiu["total_donasi"] = pd.to_numeric(donasiu["total_donasi"])
donasiu
# Out:
#         ID                             name  ...      status metode_pembayaran
# 0    26790                 alvandha adindra  ...  settlement     bank_transfer
# 1    26791            ruhendi tirta kusumah  ...  settlement            emoney
# 2    26792  ibu ari /jbb/najumas/hs2/koalum  ...  settlement     bank_transfer
# 3    26793               widiastutiningtyas  ...  settlement     bank_transfer
# 4    26794                      abdul basit  ...  settlement            emoney
# ..     ...                              ...  ...         ...               ...
# 128  43379                      mahfud rofi  ...  settlement     bank_transfer
# 129  43380                      mahfud rofi  ...  settlement     bank_transfer
# 130  43381                 sari rafif pasha  ...  settlement     bank_transfer
# 131  43382                          lestari  ...  settlement     bank_transfer
# 132  43384                rintya yuniastari  ...  settlement     bank_transfer
#
# [6208 rows x 8 columns]

# %%
donasiu.describe()
# Out:
#                  ID  total_donasi
# count   6208.000000  6.208000e+03
# mean   34943.644008  2.125779e+05
# std     4781.814263  4.823703e+05
# min    26790.000000  1.000000e+00
# 25%    30622.750000  2.500000e+04
# 50%    35062.000000  1.000000e+05
# 75%    38905.250000  2.000000e+05
# max    43384.000000  1.000000e+07

# %%
donasiu['total_donasi'].sum(axis = 0,skipna = True )
# Out:
# 1319683312.0

# %%
#Mencari Variable yang memiliki missing value
zakatu.isnull().sum()
# Out:
# ID                   0
# name                 0
# platform             1
# category             0
# tanggal              0
# total_zakat          0
# status               0
# metode_pembayaran    0
# dtype: int64

# %%
zakatu["metode_pembayaran"].replace(["gopay", "OVO", "echannel","DANA","LINKAJA"],"emoney", inplace=True)
zakatu["metode_pembayaran"].replace(["BNI","BRI","MANDIRI","PERMATA","BCA - 1393000001","BRI - 013701000379303","BNI - 152010118","BCA - 1393004952","BCA - 1393040002","Mandiri - 1490010260646","Mandiri - 1320505050535","Muamalat - 4080200000","	Mandiri - 1490010260646","Mandiri Syariah - 7277777775","Mandiri - 1320505050543","Mandiri - 1320505050519","Mandiri - 1280006235151","Mandiri - 1010012312318","Mandiri Syariah - 7273737377","Mandiri - 1320006531140","Transfer Bank Mandiri Syariah - 7273737377","Muamalat - 4080300000","Transfer Bank Mandiri - 1320505050519","Mandiri - 1320020040060","Muamalat - 4080400000","Transfer Bank Mandiri - 1320505050535","CREDITCARD","credit_card"],"bank_transfer",inplace=True)
zakatu["status"].replace(["COMPLETED", "SUCCESS_COMPLETED", "PAID"],"settlement", inplace=True)
zakatu["platform"].replace("WEB", "Web",inplace = True)
zakatu['name'] = zakatu['name'].str.lower()
zakatu["platform"].fillna("Unknown", inplace = True)
zakatu["total_zakat"] = pd.to_numeric(zakatu["total_zakat"])
zakatu
# Out:
#       ID                        name  ...      status metode_pembayaran
# 0   2689  dirga imam gozali sumantri  ...  settlement            emoney
# 1   2690    putu berly calvina izumi  ...  settlement     bank_transfer
# 2   2691          pak saeful rokhman  ...  settlement     bank_transfer
# 3   2692    vinanda langgeng kencana  ...  settlement     bank_transfer
# 4   2693                      novias  ...  settlement     bank_transfer
# ..   ...                         ...  ...         ...               ...
# 7   4031                 fara kirana  ...  settlement     bank_transfer
# 8   4032   libonit poetry mayangsari  ...  settlement     bank_transfer
# 9   4034              nike pudjiwati  ...  settlement     bank_transfer
# 10  4035               helena shinta  ...  settlement     bank_transfer
# 11  4036               ima gusnandar  ...  settlement     bank_transfer
#
# [337 rows x 8 columns]

# %%
zakatu.describe()
# Out:
#                 ID   total_zakat
# count   337.000000  3.370000e+02
# mean   3388.264095  5.802936e+05
# std     501.750328  1.389357e+06
# min    2689.000000  1.000000e+00
# 25%    2846.000000  1.500000e+05
# 50%    3698.000000  2.500000e+05
# 75%    3837.000000  5.000000e+05
# max    4036.000000  1.162500e+07

# %%
zakatu['total_zakat'].sum(axis = 0,skipna = True )
# Out:
# 195558947.0

# %% [markdown]
# #Analythical

# %% [markdown]
# ## Analisis metode pembayaran Donasi dan Zakat

# %%
plt.figure(figsize = (30,20))
plt.subplot(2,4,1)
plt.title("Donasi guest")
piechart_donasiguest = donasig['metode_pembayaran'].value_counts()
piechart_donasiguest.plot.pie(autopct='%.2f%%')

plt.subplot(2,4,2)
plt.title("Donasi user")
piechart_donasiuser = donasiu['metode_pembayaran'].value_counts()
piechart_donasiuser.plot.pie(autopct='%.2f%%')

plt.figure(figsize = (30,20))
plt.subplot(2,4,3)
plt.title("Zakat guest")
piechart_zakatguest = zakatg['metode_pembayaran'].value_counts()
piechart_zakatguest.plot.pie(autopct='%.2f%%')

plt.subplot(2,4,4)
plt.title("Zakat user")
piechart_zakatuser = zakatu['metode_pembayaran'].value_counts()
piechart_zakatuser.plot.pie(autopct='%.2f%%')

plt.show()

# %% [markdown]
# ## Analisis kategori pembayaran zakat

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,2,1)
sns.countplot(x ='category', data = zakatg)
plt.title("Distribution Guest Category")

plt.subplot(1,2,2)
sns.countplot(x ='category', data = zakatu)
plt.title("Distribution User Category")

plt.show()

# %% [markdown]
# ## Analisis Platform donasi

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,2,1)
sns.countplot(x ='platform', data = zakatg)
plt.title("Distribution Guest platform")

plt.subplot(1,2,2)
sns.countplot(x ='platform', data = zakatu)
plt.title("Distribution User platform")

plt.show()

# %% [markdown]
# ## Analisis perbandingan metode pembayaran donasi user melalui platform

# %%
figsize = (15,7)
sns.catplot(x='platform',data=donasiu, kind='count', hue='metode_pembayaran', aspect=2)

# %% [markdown]
# ## Analisis perbandingan metode pembayaran donasi guest melalui platform

# %%
figsize = (15,7)
sns.catplot(x='platform',data=donasig, kind='count', hue='metode_pembayaran', aspect=2)

# %% [markdown]
# ## Analisis perbandingan pembayaran zakat guest per kategori

# %%
figsize = (15,7)
sns.catplot(x='category',data=zakatg, kind='count', hue='metode_pembayaran', aspect=2)

# %% [markdown]
# ## Analisis perbandingan pembayaran zakat user per kategori

# %%
figsize = (15,7)
sns.catplot(x='category',data=zakatu, kind='count', hue='metode_pembayaran', aspect=2)

# %% [markdown]
# #Forecasting

# %% [markdown]
# ##Users

# %% [markdown]
# ###Donasi

# %%
donasiu.dtypes
# Out:
# ID                     int64
# name                  object
# platform              object
# judul                 object
# tanggal               object
# total_donasi         float64
# status                object
# metode_pembayaran     object
# dtype: object

# %%
import datetime
from datetime import date
donasiu['tanggal'] = pd.to_datetime(donasiu['tanggal']).dt.strftime('%Y-%m-%d')

# %%
donasiu.dtypes
# Out:
# ID                     int64
# name                  object
# platform              object
# judul                 object
# tanggal               object
# total_donasi         float64
# status                object
# metode_pembayaran     object
# dtype: object

# %%
datadonasiu = donasiu.drop(columns= ['ID','name', 'platform', 'judul', 'status', 'metode_pembayaran'])
datadonasiu.head()
# Out:
#       tanggal  total_donasi
# 0  2021-01-01       50000.0
# 1  2021-01-01      100000.0
# 2  2021-01-01      100000.0
# 3  2021-01-01     1000720.0
# 4  2021-01-01        5000.0

# %%
datadonasiu = datadonasiu.groupby('tanggal').sum()

# %%
#Set Index
datadonasiu.index = pd.to_datetime(datadonasiu.index)
datadonasiu.index = datadonasiu.index.to_period('D').to_timestamp('D')

# %%
datadonasiu.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2021-11-27', '2021-11-28', '2021-11-29', '2021-11-30',
#                '2021-12-01', '2021-12-02', '2021-12-03', '2021-12-04',
#                '2021-12-05', '2021-12-06'],
#               dtype='datetime64[ns]', name='tanggal', length=340, freq='D')

# %% [markdown]
# ####Statistical Approach

# %% [markdown]
# ##### Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

df_ses = datadonasiu.copy()

model_ses = SimpleExpSmoothing(datadonasiu['total_donasi'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) 
df_ses['SES'] = fitted_model_ses.fittedvalues

df_ses.head(20)
# Out:
#             total_donasi           SES
# tanggal
# 2021-01-01     9104921.0  9.104921e+06
# 2021-01-02    18147735.0  9.104921e+06
# 2021-01-03     4549815.0  1.181777e+07
# 2021-01-04     7592243.0  9.637380e+06
# 2021-01-05     5388900.0  9.023839e+06
# 2021-01-06     2870662.0  7.933357e+06
# 2021-01-07     6625387.0  6.414549e+06
# 2021-01-08    11453135.0  6.477800e+06
# 2021-01-09     2505627.0  7.970401e+06
# 2021-01-10      555133.0  6.330969e+06
# 2021-01-11     8727754.0  4.598218e+06
# 2021-01-12     2604622.0  5.837079e+06
# 2021-01-13     3686127.0  4.867342e+06
# 2021-01-14    13748226.0  4.512977e+06
# 2021-01-15     8869400.0  7.283552e+06
# 2021-01-16     1991573.0  7.759306e+06
# 2021-01-17      721452.0  6.028986e+06
# 2021-01-18     2031102.0  4.436726e+06
# 2021-01-19     2640190.0  3.715039e+06
# 2021-01-20     3704416.0  3.392584e+06

# %%
df_ses.plot()

# %%
# Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df_es = datadonasiu.copy()

model = ExponentialSmoothing(datadonasiu['total_donasi'], trend = 'add') 
fitted_model = model.fit()
df_es['ES'] = fitted_model.fittedvalues.shift(-1)

df_es.head(20)
# Out:
#             total_donasi            ES
# tanggal
# 2021-01-01     9104921.0  9.104921e+06
# 2021-01-02    18147735.0  1.040643e+07
# 2021-01-03     4549815.0  9.563503e+06
# 2021-01-04     7592243.0  9.279784e+06
# 2021-01-05     5388900.0  8.719777e+06
# 2021-01-06     2870662.0  7.877926e+06
# 2021-01-07     6625387.0  7.697651e+06
# 2021-01-08    11453135.0  8.238170e+06
# 2021-01-09     2505627.0  7.413097e+06
# 2021-01-10      555133.0  6.426044e+06
# 2021-01-11     8727754.0  6.757324e+06
# 2021-01-12     2604622.0  6.159634e+06
# 2021-01-13     3686127.0  5.803628e+06
# 2021-01-14    13748226.0  6.947077e+06
# 2021-01-15     8869400.0  7.223753e+06
# 2021-01-16     1991573.0  6.470696e+06
# 2021-01-17      721452.0  5.643219e+06
# 2021-01-18     2031102.0  5.123335e+06
# 2021-01-19     2640190.0  4.765941e+06
# 2021-01-20     3704416.0  4.613158e+06

# %%
df_es.plot()

# %%
datadonasiu.shape
# Out:
# (340, 1)

# %%
test_data = datadonasiu.iloc[237:]
train_data = datadonasiu.iloc[:238]

# %%
fitted_model = ExponentialSmoothing(train_data['total_donasi'],
                                   trend = 'add', 
                                   seasonal = 'add', 
                                   seasonal_periods = 24).fit()

# %%
test_predictions = fitted_model.forecast(120)

# %%
train_data['total_donasi'].plot(legend=True, label = 'Train',
                             figsize = (12,5))
test_data['total_donasi'].plot(legend=True, label = 'Test')
test_predictions.plot(legend=True, label = 'Prediction')

# %%
# performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(test_data['total_donasi'],test_predictions[:103]))
print("MSE: ",mean_squared_error(test_data['total_donasi'],test_predictions[:103]))
print("RMSE: ", np.sqrt(mean_squared_error(test_data['total_donasi'],test_predictions[:103])))
print("R2: ",r2_score(test_data['total_donasi'],test_predictions[:103]))
print("")
# Out:
# Exponential Smoothing
# MAE:  2861783.015360989
# MSE:  12664120183781.518
# RMSE:  3558668.3160673343
# R2:  -0.44607696710666067

# %% [markdown]
# #####ARIMA

# %%
train=datadonasiu.iloc[:272]
test=datadonasiu.iloc[271:]

train
# Out:
#             total_donasi
# tanggal
# 2021-01-01     9104921.0
# 2021-01-02    18147735.0
# 2021-01-03     4549815.0
# 2021-01-04     7592243.0
# 2021-01-05     5388900.0
# ...                  ...
# 2021-09-25     1376000.0
# 2021-09-26      370999.0
# 2021-09-27     2980016.0
# 2021-09-28     2785673.0
# 2021-09-29     4042000.0
#
# [272 rows x 1 columns]

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(train['total_donasi'],order=(1,1,7)) # (p -> AR, d -> I (stationarity) , q -> MA)
results=model.fit()

# %%
predictions=results.predict(start,end,typ='levels').rename('ARIMA(1,1,7) Predictions')

# %%
test['total_donasi'].plot(legend=True)
predictions.plot(legend=True)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("ARIMA")
print("MAE: ",mean_absolute_error(test['total_donasi'],predictions))
print("MSE: ",mean_squared_error(test['total_donasi'],predictions))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_donasi'],predictions)))
print("R2: ",r2_score(test['total_donasi'],predictions))
print("")
# Out:
# ARIMA
# MAE:  1978003.116794749
# MSE:  9694523169240.977
# RMSE:  3113602.9241444673
# R2:  -0.11499256835693061

# %%
# Forecast into future
model=ARIMA(datadonasiu['total_donasi'],order=(1,1,7))
results=model.fit()
fcast=results.predict(start=len(datadonasiu),end=len(datadonasiu)+36,typ='levels').rename('ARIMA(1,1,1) forecast')

# %%
datadonasiu['total_donasi'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train['total_donasi'],order=(1,1,7),seasonal_order=(1,1,1,7))
results=model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
predictions1=results.predict(start,end,typ='levels').rename('SARIMA Predictions')

# %%
test['total_donasi'].plot(legend=True,figsize=(8,5))
predictions1.plot(legend=True)

# %%
print("SARIMAX")
print("MAE: ",mean_absolute_error(test['total_donasi'],predictions1))
print("MSE: ",mean_squared_error(test['total_donasi'],predictions1))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_donasi'],predictions1)))
print("R2: ",r2_score(test['total_donasi'],predictions1))
print("")
# Out:
# SARIMAX
# MAE:  2633221.2636294514
# MSE:  12902718073298.918
# RMSE:  3592035.366376411
# R2:  -0.48397548927198253

# %%
model=SARIMAX(datadonasiu['total_donasi'],order=(1,1,1),seasonal_order=(1,1,1,7))
results=model.fit()
fcast=results.predict(start=len(datadonasiu),end=len(datadonasiu)+36,typ='levels').rename('SARIMA Forecast')

# %%
datadonasiu['total_donasi'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %% [markdown]
# ####Machine Learning Approach

# %% [markdown]
# #####Basic Model ML

# %%
def LaggedFeatures(s,lag=2,fillna=True, dropna=False):
    if type(s) is pd.DataFrame:
        new_dict={}
        for col_name in s:
            new_dict[col_name]=s[col_name]
            # create lagged Series
            for l in range(1,lag+1):
                new_dict['%s_lag%d' %(col_name,l)]=s[col_name].shift(l)
        res=pd.DataFrame(new_dict,index=s.index)

    elif type(s) is pd.Series:
        the_range=range(lag+1)
        res=pd.concat([s.shift(i) for i in the_range],axis=1)
        res.columns=['lag_%d' %i for i in the_range]
    else:
        print ('Only works for DataFrame or Series')
        return None
    if dropna:
        res = res.dropna()
    else:
        res = res
    if fillna:
        return res.fillna(0)
    else:
        return res

# %%
lag1 = LaggedFeatures(datadonasiu,lag=7,fillna=True, dropna=True)
lag1.shape
# Out:
# (333, 8)

# %%
train = lag1.iloc[:272]
test = lag1.iloc[271:]
train
# Out:
#             total_donasi  ...  total_donasi_lag7
# tanggal                   ...
# 2021-01-08    11453135.0  ...          9104921.0
# 2021-01-09     2505627.0  ...         18147735.0
# 2021-01-10      555133.0  ...          4549815.0
# 2021-01-11     8727754.0  ...          7592243.0
# 2021-01-12     2604622.0  ...          5388900.0
# ...                  ...  ...                ...
# 2021-10-02     1974500.0  ...          1376000.0
# 2021-10-03     2435475.0  ...           370999.0
# 2021-10-04     1300000.0  ...          2980016.0
# 2021-10-05     1860981.0  ...          2785673.0
# 2021-10-06     1170000.0  ...          4042000.0
#
# [272 rows x 8 columns]

# %%
X_train = train.drop(['total_donasi'], axis=1)
X_test = test.drop(['total_donasi'], axis=1)

y_train = train['total_donasi']
y_test = test ['total_donasi']


X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

rf = RandomForestRegressor()
lr = LinearRegression()

#train
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np


y_pred_rf = rf.predict(X_test)
y_pred_lr = lr.predict(X_test)


print("Random Forest Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
print("MSE: ",mean_squared_error(y_test,y_pred_rf))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("R2: ",r2_score(y_test,y_pred_rf))
print("")

print("Linear Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
print("MSE: ",mean_squared_error(y_test,y_pred_lr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
print("R2: ",r2_score(y_test,y_pred_lr))
print("")
# Out:
# Random Forest Regression
# MAE:  1885507.941129032
# MSE:  5398472928532.431
# RMSE:  2323461.4110271838
# R2:  0.2405464833503559
#
# Linear Regression
# MAE:  1981864.9416631549
# MSE:  5928403087312.196
# RMSE:  2434831.223578381
# R2:  0.16599626739263595

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(18,6)) 

axs[0].plot(y_test,label='real values')
axs[0].plot(y_pred_rf,label='predicted values')
axs[0].set_title("Random Forest")
axs[0].legend()

axs[1].plot(y_test,label='real values')
axs[1].plot(y_pred_lr,label='predicted values')
axs[1].set_title("Linear Regression")
axs[1].legend()

# %% [markdown]
# #####LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from pandas.tseries.offsets import DateOffset
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#datadonasiu = datadonasiu.set_index('tanggal')

# %%
datadonasiu.index.to_pydatetime()
# Out:
# array([datetime.datetime(2021, 1, 1, 0, 0),
#        datetime.datetime(2021, 1, 2, 0, 0),
#        datetime.datetime(2021, 1, 3, 0, 0),
#        datetime.datetime(2021, 1, 4, 0, 0),
#        datetime.datetime(2021, 1, 5, 0, 0),
#        datetime.datetime(2021, 1, 6, 0, 0),
#        datetime.datetime(2021, 1, 7, 0, 0),
#        datetime.datetime(2021, 1, 8, 0, 0),
#        datetime.datetime(2021, 1, 9, 0, 0),
#        datetime.datetime(2021, 1, 10, 0, 0),
#        datetime.datetime(2021, 1, 11, 0, 0),
#        datetime.datetime(2021, 1, 12, 0, 0),
#        datetime.datetime(2021, 1, 13, 0, 0),
#        datetime.datetime(2021, 1, 14, 0, 0),
#        datetime.datetime(2021, 1, 15, 0, 0),
#        datetime.datetime(2021, 1, 16, 0, 0),
#        datetime.datetime(2021, 1, 17, 0, 0),
#        datetime.datetime(2021, 1, 18, 0, 0),
#        datetime.datetime(2021, 1, 19, 0, 0),
#        datetime.datetime(2021, 1, 20, 0, 0),
#        datetime.datetime(2021, 1, 21, 0, 0),
# ...

# %%
datadonasiu.dtypes
# Out:
# total_donasi    float64
# dtype: object

# %%
datadonasiu
# Out:
#             total_donasi
# tanggal
# 2021-01-01     9104921.0
# 2021-01-02    18147735.0
# 2021-01-03     4549815.0
# 2021-01-04     7592243.0
# 2021-01-05     5388900.0
# ...                  ...
# 2021-12-02     7427500.0
# 2021-12-03    14735138.0
# 2021-12-04     2980042.0
# 2021-12-05     1260000.0
# 2021-12-06      890000.0
#
# [340 rows x 1 columns]

# %%
train_df = datadonasiu[:len(datadonasiu)-12]
test_df = datadonasiu[len(datadonasiu)-12:]

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)
train = scaler.transform(train_df)
test = scaler.transform(test_df)

# %%
n_input = 90
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator,epochs=90, verbose= 0)
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_9 (LSTM)               (None, 200)               161600
#
#  dropout_9 (Dropout)         (None, 200)               0
#
#  dense_9 (Dense)             (None, 1)                 201
#
# ...
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_list = []
batch = train[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=datazakatu[-n_input:].index, columns=['Prediction'])
df_test = pd.concat([datazakatu,df_predict], axis=1)

# %%
print("LSTM")
print("MAE: ",mean_absolute_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("MSE: ",mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("RMSE: ", np.sqrt(mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1])))
print("R2: ",r2_score(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("")
# Out:
# LSTM
# MAE:  3032551.5902611385
# MSE:  9754165306708.07
# RMSE:  3123165.910852011
# R2:  -16.486933157637388

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test['total_zakat'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ###Zakat

# %%
zakatu.dtypes
# Out:
# ID                     int64
# name                  object
# platform              object
# category              object
# tanggal               object
# total_zakat          float64
# status                object
# metode_pembayaran     object
# dtype: object

# %%
import datetime
from datetime import date
zakatu['tanggal'] = pd.to_datetime(zakatu['tanggal']).dt.strftime('%Y-%m-%d')

# %%
datazakatu = zakatu.drop(columns= ['ID','name', 'platform', 'category', 'status', 'metode_pembayaran'])
datazakatu.head()
# Out:
#       tanggal  total_zakat
# 0  2021-01-01    6000000.0
# 1  2021-01-04     100000.0
# 2  2021-01-04     300000.0
# 3  2021-01-04    1000000.0
# 4  2021-01-04      55000.0

# %%
datazakatu = datazakatu.groupby('tanggal').sum()

# %%
#Set Index
datazakatu.index = pd.to_datetime(datazakatu.index)
datazakatu.index = datazakatu.index.to_period('D').to_timestamp('D')

# %%
datazakatu.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07', '2021-01-08', '2021-01-09', '2021-01-11',
#                '2021-01-12', '2021-01-15',
#                ...
#                '2021-11-24', '2021-11-25', '2021-11-26', '2021-11-27',
#                '2021-11-29', '2021-12-01', '2021-12-02', '2021-12-03',
#                '2021-12-04', '2021-12-05'],
#               dtype='datetime64[ns]', name='tanggal', length=177, freq=None)

# %% [markdown]
# ####Statistical Approach

# %% [markdown]
# #####Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

df_ses = datazakatu.copy()

model_ses = SimpleExpSmoothing(datadonasiu['total_donasi'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) 
df_ses['SES'] = fitted_model_ses.fittedvalues

df_ses.head(20)
# Out:
#             total_zakat           SES
# tanggal
# 2021-01-01    6000000.0  9.104921e+06
# 2021-01-04    7127500.0  9.637380e+06
# 2021-01-05     500000.0  9.023839e+06
# 2021-01-06    1425000.0  7.933357e+06
# 2021-01-07    3300232.0  6.414549e+06
# 2021-01-08     700000.0  6.477800e+06
# 2021-01-09     250000.0  7.970401e+06
# 2021-01-11    1200000.0  4.598218e+06
# 2021-01-12    1000000.0  5.837079e+06
# 2021-01-15     605500.0  7.283552e+06
# 2021-01-16     500000.0  7.759306e+06
# 2021-01-20     100000.0  3.392584e+06
# 2021-01-21     250000.0  3.486134e+06
# 2021-01-22     300000.0  3.532995e+06
# 2021-01-23     250000.0  4.756825e+06
# 2021-01-25    1980000.0  3.372202e+06
# 2021-01-26    2100000.0  4.097376e+06
# 2021-01-27     785000.0  3.797541e+06
# 2021-01-28    5451250.0  4.850603e+06
# 2021-01-29    1372163.0  5.322400e+06

# %%
df_ses.plot()

# %%
# Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df_es = datazakatu.copy()

model = ExponentialSmoothing(datazakatu['total_zakat'], trend = 'add') 
fitted_model = model.fit()
df_es['ES'] = fitted_model.fittedvalues.shift(-1)

df_es.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#             total_zakat             ES
# tanggal
# 2021-01-01    6000000.0  224495.210912
# 2021-01-04    7127500.0  461135.648787
# 2021-01-05     500000.0  465466.278825
# 2021-01-06    1425000.0  500956.021408
# 2021-01-07    3300232.0  598709.957760
# 2021-01-08     700000.0  605153.321420
# 2021-01-09     250000.0  596148.826596
# 2021-01-11    1200000.0  619600.857382
# 2021-01-12    1000000.0  635490.382883
# 2021-01-15     605500.0  637490.694917
# 2021-01-16     500000.0  635852.768915
# 2021-01-20     100000.0  620732.686232
# 2021-01-21     250000.0  611200.923751
# 2021-01-22     300000.0  603683.952842
# 2021-01-23     250000.0  594729.187294
# 2021-01-25    1980000.0  644627.566007
# ...

# %%
df_es.plot()

# %%
datazakatu = datazakatu.reset_index()

# %%
datazakatu.shape
# Out:
# (177, 2)

# %%
test_data = datazakatu.iloc[123:]
train_data = datazakatu.iloc[:124]

# %%
fitted_model = ExponentialSmoothing(train_data['total_zakat'],
                                   trend = 'add', 
                                   seasonal = 'add', 
                                   seasonal_periods = 24).fit()

# %%
test_predictions = fitted_model.forecast(54)

# %%
train_data['total_zakat'].plot(legend=True, label = 'Train',
                             figsize = (12,5))
test_data['total_zakat'].plot(legend=True, label = 'Test')
test_predictions.plot(legend=True, label = 'Prediction')

# %%
# performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(test_data['total_zakat'],test_predictions[:54]))
print("MSE: ",mean_squared_error(test_data['total_zakat'],test_predictions[:54]))
print("RMSE: ", np.sqrt(mean_squared_error(test_data['total_zakat'],test_predictions[:54])))
print("R2: ",r2_score(test_data['total_zakat'],test_predictions[:54]))
print("")
# Out:
# Exponential Smoothing
# MAE:  1288305.488867658
# MSE:  5203300878628.836
# RMSE:  2281074.5008940054
# R2:  -0.47213261779524607

# %% [markdown]
# #####ARIMA

# %%
train=datazakatu.iloc[:124]
test=datazakatu.iloc[123:]

train
# Out:
#        tanggal  total_zakat
# 0   2021-01-01    6000000.0
# 1   2021-01-04    7127500.0
# 2   2021-01-05     500000.0
# 3   2021-01-06    1425000.0
# 4   2021-01-07    3300232.0
# ..         ...          ...
# 119 2021-09-17     150000.0
# 120 2021-09-22     150000.0
# 121 2021-09-24    2710000.0
# 122 2021-09-26     250000.0
# 123 2021-09-27     237500.0
#
# [124 rows x 2 columns]

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(train['total_zakat'],order=(1,1,1)) # (p -> AR, d -> I (stationarity) , q -> MA)
results=model.fit()

# %%
predictions=results.predict(start,end,typ='levels').rename('ARIMA(1,1,1) Predictions')

# %%
test['total_zakat'].plot(legend=True)
predictions.plot(legend=True)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("ARIMA")
print("MAE: ",mean_absolute_error(test['total_zakat'],predictions))
print("MSE: ",mean_squared_error(test['total_zakat'],predictions))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_zakat'],predictions)))
print("R2: ",r2_score(test['total_zakat'],predictions))
print("")
# Out:
# ARIMA
# MAE:  769609.889622262
# MSE:  3934762205651.193
# RMSE:  1983623.5040075507
# R2:  -0.11323406455279073

# %%
# Forecast into future
model=ARIMA(datazakatu['total_zakat'],order=(1,1,3))
results=model.fit()
fcast=results.predict(start=len(datazakatu),end=len(datazakatu)+36,typ='levels').rename('ARIMA(1,1,1) forecast')

# %%
datazakatu['total_zakat'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train['total_zakat'],order=(1,1,1),seasonal_order=(1,1,1,17))
results=model.fit()

# %%
predictions1=results.predict(start,end,typ='levels').rename('SARIMA Predictions')

# %%
test['total_zakat'].plot(legend=True,figsize=(8,5))
predictions1.plot(legend=True)

# %%
print("SARIMAX")
print("MAE: ",mean_absolute_error(test['total_zakat'],predictions1))
print("MSE: ",mean_squared_error(test['total_zakat'],predictions1))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_zakat'],predictions1)))
print("R2: ",r2_score(test['total_zakat'],predictions1))
print("")
# Out:
# SARIMAX
# MAE:  906716.9032876521
# MSE:  4108967379022.6133
# RMSE:  2027058.8000900748
# R2:  -0.1625206854672292

# %%
model=SARIMAX(datazakatu['total_zakat'],order=(1,1,1),seasonal_order=(1,1,1,17))
results=model.fit()
fcast=results.predict(start=len(datazakatu),end=len(datazakatu)+36,typ='levels').rename('SARIMA Forecast')

# %%
datazakatu['total_zakat'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %% [markdown]
# ####Machine Learning Approach

# %% [markdown]
# #####Basic Model

# %%
df_ml = datazakatu.copy()
df_ml.drop(['tanggal'], axis=1, inplace=True)
df_ml.head()
# Out:
#    total_zakat
# 0    6000000.0
# 1    7127500.0
# 2     500000.0
# 3    1425000.0
# 4    3300232.0

# %%
def LaggedFeatures(s,lag=2,fillna=True, dropna=False):
    if type(s) is pd.DataFrame:
        new_dict={}
        for col_name in s:
            new_dict[col_name]=s[col_name]
            # create lagged Series
            for l in range(1,lag+1):
                new_dict['%s_lag%d' %(col_name,l)]=s[col_name].shift(l)
        res=pd.DataFrame(new_dict,index=s.index)

    elif type(s) is pd.Series:
        the_range=range(lag+1)
        res=pd.concat([s.shift(i) for i in the_range],axis=1)
        res.columns=['lag_%d' %i for i in the_range]
    else:
        print ('Only works for DataFrame or Series')
        return None
    if dropna:
        res = res.dropna()
    else:
        res = res
    if fillna:
        return res.fillna(0)
    else:
        return res

# %%
lag1 = LaggedFeatures(df_ml,lag=7,fillna=True, dropna=True)
lag1.shape
# Out:
# (170, 8)

# %%
train = lag1.iloc[:124]
test = lag1.iloc[123:]
train
# Out:
#      total_zakat  total_zakat_lag1  ...  total_zakat_lag6  total_zakat_lag7
# 7      1200000.0          250000.0  ...         7127500.0         6000000.0
# 8      1000000.0         1200000.0  ...          500000.0         7127500.0
# 9       605500.0         1000000.0  ...         1425000.0          500000.0
# 10      500000.0          605500.0  ...         3300232.0         1425000.0
# 11      100000.0          500000.0  ...          700000.0         3300232.0
# ..           ...               ...  ...               ...               ...
# 126     400000.0          255000.0  ...          150000.0          150000.0
# 127     361350.0          400000.0  ...         2710000.0          150000.0
# 128     300000.0          361350.0  ...          250000.0         2710000.0
# 129     500000.0          300000.0  ...          237500.0          250000.0
# 130    1300000.0          500000.0  ...          403000.0          237500.0
#
# [124 rows x 8 columns]

# %%
X_train = train.drop(['total_zakat'], axis=1)
X_test = test.drop(['total_zakat'], axis=1)

y_train = train['total_zakat']
y_test = test ['total_zakat']


X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

rf = RandomForestRegressor()
lr = LinearRegression()

#train
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np


y_pred_rf = rf.predict(X_test)
y_pred_lr = lr.predict(X_test)


print("Random Forest Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
print("MSE: ",mean_squared_error(y_test,y_pred_rf))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("R2: ",r2_score(y_test,y_pred_rf))
print("")

print("Linear Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
print("MSE: ",mean_squared_error(y_test,y_pred_lr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
print("R2: ",r2_score(y_test,y_pred_lr))
print("")
# Out:
# Random Forest Regression
# MAE:  959308.5857446808
# MSE:  4473451932891.665
# RMSE:  2115053.647757348
# R2:  -0.12218126277553054
#
# Linear Regression
# MAE:  953575.0102892353
# MSE:  4026958059828.0435
# RMSE:  2006728.1977956167
# R2:  -0.010176693192015973

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(18,6)) 

axs[0].plot(y_test,label='real values')
axs[0].plot(y_pred_rf,label='predicted values')
axs[0].set_title("Random Forest")
axs[0].legend()

axs[1].plot(y_test,label='real values')
axs[1].plot(y_pred_lr,label='predicted values')
axs[1].set_title("Linear Regression")
axs[1].legend()

# %% [markdown]
# #####LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from pandas.tseries.offsets import DateOffset
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
datazakatu = datazakatu.set_index('tanggal')

# %%
datazakatu
# Out:
#             total_zakat
# tanggal
# 2021-01-01    6000000.0
# 2021-01-04    7127500.0
# 2021-01-05     500000.0
# 2021-01-06    1425000.0
# 2021-01-07    3300232.0
# ...                 ...
# 2021-12-01    1929000.0
# 2021-12-02     670000.0
# 2021-12-03     750000.0
# 2021-12-04     100000.0
# 2021-12-05     900000.0
#
# [177 rows x 1 columns]

# %%
train_df = datazakatu[:len(datazakatu)-12]
test_df = datazakatu[len(datazakatu)-12:]

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)
train = scaler.transform(train_df)
test = scaler.transform(test_df)

# %%
n_input = 25
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator,epochs=90, verbose= 0)
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 200)               161600
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_3 (Dense)             (None, 1)                 201
#
# ...
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_list = []
batch = train[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=datazakatu[-n_input:].index, columns=['Prediction'])
df_test = pd.concat([datazakatu,df_predict], axis=1)

# %%
print("LSTM")
print("MAE: ",mean_absolute_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("MSE: ",mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("RMSE: ", np.sqrt(mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1])))
print("R2: ",r2_score(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("")
# Out:
# LSTM
# MAE:  723421.1327475011
# MSE:  637255684132.966
# RMSE:  798282.9599415022
# R2:  -0.14245014333456352

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test['total_zakat'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Guest

# %% [markdown]
# ### Donasi

# %%
donasig.info
# Out:
# <bound method DataFrame.info of         ID        nama_lengkap  ...      status metode_pembayaran
# 0    27022    putu darma putra  ...  settlement            emoney
# 1    27045         hamba allah  ...  settlement     bank_transfer
# 2    27055         evi wirawan  ...  settlement     bank_transfer
# 3    27061             achmadi  ...  settlement     bank_transfer
# 4    27083          lia soraya  ...  settlement     bank_transfer
# ..     ...                 ...  ...         ...               ...
# 127  43371            prajitno  ...  settlement            emoney
# 128  43372                yudi  ...  settlement            emoney
# 129  43373              taufik  ...  settlement     bank_transfer
# 130  43374  fajar sovin namiya  ...  settlement     bank_transfer
# 131  43378  mawaddah khairiyah  ...  settlement            emoney
#
# [2873 rows x 8 columns]>

# %%
donasig.dtypes
# Out:
# ID                     int64
# nama_lengkap          object
# platform              object
# judul                 object
# tanggal               object
# total_donasi         float64
# status                object
# metode_pembayaran     object
# dtype: object

# %%
import datetime
from datetime import date

# %%
donasig['tanggal'] = pd.to_datetime(donasig['tanggal']).dt.strftime('%Y-%m-%d')

# %%
donasig
# Out:
#         ID        nama_lengkap  ...      status metode_pembayaran
# 0    27022    putu darma putra  ...  settlement            emoney
# 1    27045         hamba allah  ...  settlement     bank_transfer
# 2    27055         evi wirawan  ...  settlement     bank_transfer
# 3    27061             achmadi  ...  settlement     bank_transfer
# 4    27083          lia soraya  ...  settlement     bank_transfer
# ..     ...                 ...  ...         ...               ...
# 127  43371            prajitno  ...  settlement            emoney
# 128  43372                yudi  ...  settlement            emoney
# 129  43373              taufik  ...  settlement     bank_transfer
# 130  43374  fajar sovin namiya  ...  settlement     bank_transfer
# 131  43378  mawaddah khairiyah  ...  settlement            emoney
#
# [2873 rows x 8 columns]

# %%
donasiguest = donasig.drop(columns= ['ID','nama_lengkap', 'platform', 'judul', 'status', 'metode_pembayaran'])
donasiguest
# Out:
#         tanggal  total_donasi
# 0    2021-01-05       20000.0
# 1    2021-01-05      130662.0
# 2    2021-01-05       25000.0
# 3    2021-01-05      100140.0
# 4    2021-01-06       50000.0
# ..          ...           ...
# 127  2021-12-06       20000.0
# 128  2021-12-06       20000.0
# 129  2021-12-06       20000.0
# 130  2021-12-06       20000.0
# 131  2021-12-06       20000.0
#
# [2873 rows x 2 columns]

# %%
donasiguest.dtypes
# Out:
# tanggal          object
# total_donasi    float64
# dtype: object

# %%
import matplotlib.pyplot as plt

donasiguest.plot()

# %%
donasiguest = donasiguest.groupby('tanggal').sum()

# %%
donasiguest.index = pd.to_datetime(donasiguest.index)
donasiguest.index = donasiguest.index.to_period('D').to_timestamp('D')

# %%
donasiguest.index
# Out:
# DatetimeIndex(['2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14',
#                ...
#                '2021-11-27', '2021-11-28', '2021-11-29', '2021-11-30',
#                '2021-12-01', '2021-12-02', '2021-12-03', '2021-12-04',
#                '2021-12-05', '2021-12-06'],
#               dtype='datetime64[ns]', name='tanggal', length=329, freq=None)

# %% [markdown]
# #### Statistical Approach

# %% [markdown]
# ##### Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

df_ses = donasiguest.copy()

model_ses = SimpleExpSmoothing(donasiguest['total_donasi'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) 
df_ses['SES'] = fitted_model_ses.fittedvalues

df_ses.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#             total_donasi           SES
# tanggal
# 2021-01-05      275802.0  2.758020e+05
# 2021-01-06     1770315.0  2.758020e+05
# 2021-01-07      502000.0  7.241559e+05
# 2021-01-08     1040081.0  6.575091e+05
# 2021-01-09       20000.0  7.722807e+05
# 2021-01-10     2256000.0  5.465965e+05
# 2021-01-11     2600901.0  1.059418e+06
# 2021-01-12     3791408.0  1.521863e+06
# 2021-01-13       20000.0  2.202726e+06
# 2021-01-14     2253549.0  1.547908e+06
# 2021-01-15     1676962.0  1.759601e+06
# 2021-01-16      853000.0  1.734809e+06
# 2021-01-17      750608.0  1.470266e+06
# 2021-01-18      310062.0  1.254369e+06
# 2021-01-19     1120180.0  9.710768e+05
# 2021-01-20       25000.0  1.015808e+06
# ...

# %%
df_ses.plot()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df_es = donasiguest.copy()

model = ExponentialSmoothing(donasiguest['total_donasi'], trend = 'add') # try mul
fitted_model = model.fit()
df_es['ES'] = fitted_model.fittedvalues.shift(-1)

df_es.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#             total_donasi            ES
# tanggal
# 2021-01-05      275802.0  2.339379e+06
# 2021-01-06     1770315.0  3.354220e+06
# 2021-01-07      502000.0  3.855155e+06
# 2021-01-08     1040081.0  4.316705e+06
# 2021-01-09       20000.0  4.403950e+06
# 2021-01-10     2256000.0  4.894220e+06
# 2021-01-11     2600901.0  5.316533e+06
# 2021-01-12     3791408.0  5.870296e+06
# 2021-01-13       20000.0  5.443063e+06
# 2021-01-14     2253549.0  5.506052e+06
# 2021-01-15     1676962.0  5.374522e+06
# 2021-01-16      853000.0  5.026123e+06
# 2021-01-17      750608.0  4.656628e+06
# 2021-01-18      310062.0  4.200096e+06
# 2021-01-19     1120180.0  3.950876e+06
# 2021-01-20       25000.0  3.463369e+06
# ...

# %%
df_es.plot()

# %%
donasiguest = donasiguest.reset_index()

# %%
test_data = donasiguest.iloc[237:]
train_data = donasiguest.iloc[:238]

# %%
fitted_model = ExponentialSmoothing(train_data['total_donasi'],
                                   trend = 'add', 
                                   seasonal = 'add', 
                                   seasonal_periods = 24).fit()

# %%
test_predictions = fitted_model.forecast(120)

# %%
train_data['total_donasi'].plot(legend=True, label = 'Train',
                             figsize = (12,5))
test_data['total_donasi'].plot(legend=True, label = 'Test')
test_predictions.plot(legend=True, label = 'Prediction')

# %%
# performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(test_data['total_donasi'],test_predictions[:103]))
print("MSE: ",mean_squared_error(test_data['total_donasi'],test_predictions[:103]))
print("RMSE: ", np.sqrt(mean_squared_error(test_data['total_donasi'],test_predictions[:103])))
print("R2: ",r2_score(test_data['total_donasi'],test_predictions[:103]))
print("")

# %% [markdown]
# #####ARIMA

# %%
train=donasiguest.iloc[:272]
test=donasiguest.iloc[271:]

train
# Out:
#        tanggal  total_donasi
# 0   2021-01-05      275802.0
# 1   2021-01-06     1770315.0
# 2   2021-01-07      502000.0
# 3   2021-01-08     1040081.0
# 4   2021-01-09       20000.0
# ..         ...           ...
# 267 2021-10-06     1200000.0
# 268 2021-10-07     1305000.0
# 269 2021-10-08     3308303.0
# 270 2021-10-09     4500000.0
# 271 2021-10-10      300000.0
#
# [272 rows x 2 columns]

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
from statsmodels.tsa.arima_model import ARIMA

model=ARIMA(train['total_donasi'],order=(1,1,1)) # (p -> AR, d -> I (stationarity) , q -> MA)
results=model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
predictions=results.predict(start,end,typ='levels').rename('ARIMA(1,1,1) Predictions')

# %%
test['total_donasi'].plot(legend=True)
predictions.plot(legend=True)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("ARIMA")
print("MAE: ",mean_absolute_error(test['total_donasi'],predictions))
print("MSE: ",mean_squared_error(test['total_donasi'],predictions))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_donasi'],predictions)))
print("R2: ",r2_score(test['total_donasi'],predictions))
print("")
# Out:
# ARIMA
# MAE:  1182271.211619201
# MSE:  2316666961921.1846
# RMSE:  1522060.1045691937
# R2:  -0.0680643886228205

# %%
# Forecast into future
model=ARIMA(donasiguest['total_donasi'],order=(1,1,1))
results=model.fit()
fcast=results.predict(start=len(donasiguest),end=len(donasiguest)+36,typ='levels').rename('ARIMA(1,1,1) forecast')

# %%
donasiguest['total_donasi'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
predictions1=results.predict(start,end,typ='levels').rename('SARIMA Predictions')

# %%
test['total_donasi'].plot(legend=True,figsize=(8,5))
predictions1.plot(legend=True)

# %%
print("SARIMAX")
print("MAE: ",mean_absolute_error(test['total_donasi'],predictions1))
print("MSE: ",mean_squared_error(test['total_donasi'],predictions1))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_donasi'],predictions1)))
print("R2: ",r2_score(test['total_donasi'],predictions1))
print("")
# Out:
# SARIMAX
# MAE:  935353.3078510797
# MSE:  1530608288435.7498
# RMSE:  1237177.5492772853
# R2:  0.2943361162048773

# %%
model=SARIMAX(donasiguest['total_donasi'],order=(1,1,1),seasonal_order=(1,0,0,12))
results=model.fit()
fcast=results.predict(start=len(donasiguest),end=len(donasiguest)+36,typ='levels').rename('SARIMA Forecast')

# %%
donasiguest['total_donasi'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %% [markdown]
# #### Machine Learning Approach

# %%
donasiguest
# Out:
#        tanggal  total_donasi
# 0   2021-01-05      275802.0
# 1   2021-01-06     1770315.0
# 2   2021-01-07      502000.0
# 3   2021-01-08     1040081.0
# 4   2021-01-09       20000.0
# ..         ...           ...
# 324 2021-12-02     2030424.0
# 325 2021-12-03     6612809.0
# 326 2021-12-04     1533750.0
# 327 2021-12-05     1970000.0
# 328 2021-12-06      150000.0
#
# [329 rows x 2 columns]

# %%
ml = donasiguest.copy()
ml = donasiguest.drop(columns= ['tanggal'])
ml
# Out:
#      total_donasi
# 0        275802.0
# 1       1770315.0
# 2        502000.0
# 3       1040081.0
# 4         20000.0
# ..            ...
# 324     2030424.0
# 325     6612809.0
# 326     1533750.0
# 327     1970000.0
# 328      150000.0
#
# [329 rows x 1 columns]

# %%
def LaggedFeatures(s,lag=2,fillna=True, dropna=False):
    if type(s) is pd.DataFrame:
        new_dict={}
        for col_name in s:
            new_dict[col_name]=s[col_name]
            # create lagged Series
            for l in range(1,lag+1):
                new_dict['%s_lag%d' %(col_name,l)]=s[col_name].shift(l)
        res=pd.DataFrame(new_dict,index=s.index)

    elif type(s) is pd.Series:
        the_range=range(lag+1)
        res=pd.concat([s.shift(i) for i in the_range],axis=1)
        res.columns=['lag_%d' %i for i in the_range]
    else:
        print ('Only works for DataFrame or Series')
        return None
    if dropna:
        res = res.dropna()
    else:
        res = res
    if fillna:
        return res.fillna(0)
    else:
        return res

# %%
lag1 = LaggedFeatures(ml,lag=3,fillna=True, dropna=True)
lag1.shape
# Out:
# (326, 4)

# %%
train = lag1.iloc[:264]
test = lag1.iloc[264:]
train
# Out:
#      total_donasi  total_donasi_lag1  total_donasi_lag2  total_donasi_lag3
# 3       1040081.0           502000.0          1770315.0           275802.0
# 4         20000.0          1040081.0           502000.0          1770315.0
# 5       2256000.0            20000.0          1040081.0           502000.0
# 6       2600901.0          2256000.0            20000.0          1040081.0
# 7       3791408.0          2600901.0          2256000.0            20000.0
# ..            ...                ...                ...                ...
# 262     5196414.0          1490003.0          2400007.0          2222009.0
# 263     1220000.0          5196414.0          1490003.0          2400007.0
# 264      380503.0          1220000.0          5196414.0          1490003.0
# 265     4910000.0           380503.0          1220000.0          5196414.0
# 266      520235.0          4910000.0           380503.0          1220000.0
#
# [264 rows x 4 columns]

# %%
X_train = train.drop(['total_donasi'], axis=1)
X_test = test.drop(['total_donasi'], axis=1)

y_train = train['total_donasi']
y_test = test ['total_donasi']


X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

rf = RandomForestRegressor()
lr = LinearRegression()

#train
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np


y_pred_rf = rf.predict(X_test)
y_pred_lr = lr.predict(X_test)


print("Random Forest Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
print("MSE: ",mean_squared_error(y_test,y_pred_rf))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("R2: ",r2_score(y_test,y_pred_rf))
print("")

print("Linear Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
print("MSE: ",mean_squared_error(y_test,y_pred_lr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
print("R2: ",r2_score(y_test,y_pred_lr))
print("")
# Out:
# Random Forest Regression
# MAE:  1539313.7830645158
# MSE:  4988191496405.47
# RMSE:  2233425.954986077
# R2:  -1.2708225706305907
#
# Linear Regression
# MAE:  1156624.2044366447
# MSE:  2249369017459.534
# RMSE:  1499789.6577385557
# R2:  -0.024001973100886698

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(18,6)) 

axs[0].plot(y_test,label='real values')
axs[0].plot(y_pred_rf,label='predicted values')
axs[0].set_title("Random Forest")
axs[0].legend()

axs[1].plot(y_test,label='real values')
axs[1].plot(y_pred_lr,label='predicted values')
axs[1].set_title("Linear Regression")
axs[1].legend()

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from pandas.tseries.offsets import DateOffset
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
donasiguest = donasiguest.set_index('tanggal')

# %%
donasiguest
# Out:
#             total_donasi
# tanggal
# 2021-01-05      275802.0
# 2021-01-06     1770315.0
# 2021-01-07      502000.0
# 2021-01-08     1040081.0
# 2021-01-09       20000.0
# ...                  ...
# 2021-12-02     2030424.0
# 2021-12-03     6612809.0
# 2021-12-04     1533750.0
# 2021-12-05     1970000.0
# 2021-12-06      150000.0
#
# [329 rows x 1 columns]

# %%
donasiguest.index.to_pydatetime()
# Out:
# array([datetime.datetime(2021, 1, 5, 0, 0),
#        datetime.datetime(2021, 1, 6, 0, 0),
#        datetime.datetime(2021, 1, 7, 0, 0),
#        datetime.datetime(2021, 1, 8, 0, 0),
#        datetime.datetime(2021, 1, 9, 0, 0),
#        datetime.datetime(2021, 1, 10, 0, 0),
#        datetime.datetime(2021, 1, 11, 0, 0),
#        datetime.datetime(2021, 1, 12, 0, 0),
#        datetime.datetime(2021, 1, 13, 0, 0),
#        datetime.datetime(2021, 1, 14, 0, 0),
#        datetime.datetime(2021, 1, 15, 0, 0),
#        datetime.datetime(2021, 1, 16, 0, 0),
#        datetime.datetime(2021, 1, 17, 0, 0),
#        datetime.datetime(2021, 1, 18, 0, 0),
#        datetime.datetime(2021, 1, 19, 0, 0),
#        datetime.datetime(2021, 1, 20, 0, 0),
#        datetime.datetime(2021, 1, 21, 0, 0),
#        datetime.datetime(2021, 1, 22, 0, 0),
#        datetime.datetime(2021, 1, 23, 0, 0),
#        datetime.datetime(2021, 1, 24, 0, 0),
#        datetime.datetime(2021, 1, 25, 0, 0),
# ...

# %%
train_donasiguest = donasiguest[:len(donasiguest)-60]
test_donasiguest = donasiguest[len(donasiguest)-60:]

# %%
scaler = MinMaxScaler()
scaler.fit(train_donasiguest)
train = scaler.transform(train_donasiguest)
test = scaler.transform(train_donasiguest)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator,epochs=90, verbose= 0)
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_11 (LSTM)              (None, 200)               161600
#
#  dropout_11 (Dropout)        (None, 200)               0
#
#  dense_11 (Dense)            (None, 1)                 201
#
# ...
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_list = []
batch = train[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=donasiguest[-n_input:].index, columns=['Prediction'])
df_test = pd.concat([donasiguest,df_predict], axis=1)

# %%
print("LSTM")
print("MAE: ",mean_absolute_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("MSE: ",mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("RMSE: ", np.sqrt(mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1])))
print("R2: ",r2_score(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("")
# Out:
# LSTM
# MAE:  1623672.7179624438
# MSE:  5612153623290.385
# RMSE:  2368998.443074707
# R2:  -0.2527659693665538

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test['total_donasi'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ###Zakat

# %%
zakatg.dtypes
# Out:
# ID                     int64
# nama_lengkap          object
# platform              object
# category              object
# tanggal               object
# total_zakat          float64
# status                object
# metode_pembayaran     object
# dtype: object

# %%
import datetime
from datetime import date
zakatg['tanggal'] = pd.to_datetime(zakatg['tanggal']).dt.strftime('%Y-%m-%d')

# %%
zakatg
# Out:
#        ID                nama_lengkap  ...      status metode_pembayaran
# 0    2702  muhammad ramadhan alkausar  ...  settlement            emoney
# 1    2704         muhamad haris yahya  ...  settlement     bank_transfer
# 2    2710       karunia erldi abraham  ...  settlement     bank_transfer
# 3    2718                irma suryati  ...  settlement            emoney
# 4    2739     arriman maulana makmoen  ...  settlement     bank_transfer
# ..    ...                         ...  ...         ...               ...
# 333  4019           fraskatia syahrin  ...  settlement     bank_transfer
# 334  4028       dinar swastika ardias  ...  settlement     bank_transfer
# 335  4029                 hamba allah  ...  settlement     bank_transfer
# 336  4030                 hamba allah  ...  settlement     bank_transfer
# 337  4033                       ninis  ...  settlement     bank_transfer
#
# [338 rows x 8 columns]

# %%
zakatguest = zakatg.drop(columns= ['ID','nama_lengkap', 'platform', 'category', 'status', 'metode_pembayaran'])
zakatguest.head()
# Out:
#       tanggal  total_zakat
# 0  2021-01-05     150000.0
# 1  2021-01-06     100000.0
# 2  2021-01-07    1070000.0
# 3  2021-01-09    1000000.0
# 4  2021-01-18    5000000.0

# %%
zakatguest = zakatguest.groupby('tanggal').sum()

# %%
zakatguest.index = pd.to_datetime(zakatguest.index)
zakatguest.index = zakatguest.index.to_period('D').to_timestamp('D')

# %%
zakatguest.index
# Out:
# DatetimeIndex(['2021-01-05', '2021-01-06', '2021-01-07', '2021-01-09',
#                '2021-01-18', '2021-01-27', '2021-01-29', '2021-02-05',
#                '2021-02-21', '2021-02-25', '2021-03-01', '2021-03-02',
#                '2021-03-10', '2021-03-17', '2021-03-24', '2021-03-28',
#                '2021-03-30', '2021-04-05', '2021-04-12', '2021-04-17',
#                '2021-04-23', '2021-04-29', '2021-04-30', '2021-05-03',
#                '2021-05-04', '2021-05-05', '2021-05-06', '2021-05-07',
#                '2021-05-08', '2021-05-09', '2021-05-10', '2021-05-11',
#                '2021-05-12', '2021-05-13', '2021-05-24', '2021-05-26',
#                '2021-05-29', '2021-06-09', '2021-06-18', '2021-06-27',
#                '2021-06-29', '2021-06-30', '2021-07-02', '2021-07-11',
#                '2021-07-22', '2021-07-24', '2021-08-06', '2021-09-11',
#                '2021-10-07', '2021-10-12', '2021-10-17', '2021-10-24',
# ...

# %% [markdown]
# #### Statistical Approach

# %% [markdown]
# ##### Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

df_ses = zakatguest.copy()

model_ses = SimpleExpSmoothing(zakatguest['total_zakat'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) # bisa masukin alpha
df_ses['SES'] = fitted_model_ses.fittedvalues

df_ses.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#             total_zakat           SES
# tanggal
# 2021-01-05     150000.0  1.500000e+05
# 2021-01-06     100000.0  1.500000e+05
# 2021-01-07    1070000.0  1.350000e+05
# 2021-01-09    1000000.0  4.155000e+05
# 2021-01-18    5000000.0  5.908500e+05
# 2021-01-27     200000.0  1.913595e+06
# 2021-01-29     120000.0  1.399516e+06
# 2021-02-05    1150000.0  1.015662e+06
# 2021-02-21     400000.0  1.055963e+06
# 2021-02-25     930000.0  8.591742e+05
# 2021-03-01    5000000.0  8.804219e+05
# 2021-03-02     260000.0  2.116295e+06
# 2021-03-10     185000.0  1.559407e+06
# 2021-03-17     500000.0  1.147085e+06
# 2021-03-24    1000000.0  9.529593e+05
# 2021-03-28    1500614.0  9.670715e+05
# ...

# %%
df_ses.plot()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df_es = zakatguest.copy()

model = ExponentialSmoothing(zakatguest['total_zakat'], trend = 'add') # try mul
fitted_model = model.fit()
df_es['ES'] = fitted_model.fittedvalues.shift(-1)

df_es.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#             total_zakat            ES
# tanggal
# 2021-01-05     150000.0  1.500000e+05
# 2021-01-06     100000.0  1.357407e+05
# 2021-01-07    1070000.0  4.021784e+05
# 2021-01-09    1000000.0  5.726688e+05
# 2021-01-18    5000000.0  1.835282e+06
# 2021-01-27     200000.0  1.368922e+06
# 2021-01-29     120000.0  1.012747e+06
# 2021-02-05    1150000.0  1.051890e+06
# 2021-02-21     400000.0  8.659798e+05
# 2021-02-25     930000.0  8.842375e+05
# 2021-03-01    5000000.0  2.057996e+06
# 2021-03-02     260000.0  1.545232e+06
# 2021-03-10     185000.0  1.157313e+06
# 2021-03-17     500000.0  9.698565e+05
# 2021-03-24    1000000.0  9.784530e+05
# 2021-03-28    1500614.0  1.127366e+06
# ...

# %%
df_es.plot()

# %%
zakatguest = zakatguest.reset_index()

# %%
zakatguest.shape
# Out:
# (67, 3)

# %%
test_data = zakatguest.iloc[60:]
train_data = zakatguest.iloc[:61]

# %%
fitted_model = ExponentialSmoothing(train_data['total_zakat'],
                                   trend = 'add', 
                                   seasonal = 'add', 
                                   seasonal_periods = 24).fit()

# %%
test_predictions = fitted_model.forecast(50)

# %%
train_data['total_zakat'].plot(legend=True, label = 'Train',
                             figsize = (12,5))
test_data['total_zakat'].plot(legend=True, label = 'Test')
test_predictions.plot(legend=True, label = 'Prediction')

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(test_data['total_zakat'],test_predictions[:36]))
print("MSE: ",mean_squared_error(test_data['total_zakat'],test_predictions[:36]))
print("RMSE: ", np.sqrt(mean_squared_error(test_data['total_zakat'],test_predictions[:36])))
print("R2: ",r2_score(test_data['total_zakat'],test_predictions[:36]))
print("")

# %% [markdown]
# ##### **ARIMA**

# %%
train=zakatguest.iloc[:61]
test=zakatguest.iloc[60:]

train
# Out:
#     index    tanggal  total_zakat
# 0       0 2021-01-05     150000.0
# 1       1 2021-01-06     100000.0
# 2       2 2021-01-07    1070000.0
# 3       3 2021-01-09    1000000.0
# 4       4 2021-01-18    5000000.0
# ..    ...        ...          ...
# 56     56 2021-11-05      72500.0
# 57     57 2021-11-09     170000.0
# 58     58 2021-11-18    1000000.0
# 59     59 2021-11-25     426698.0
# 60     60 2021-11-26    1031250.0
#
# [61 rows x 3 columns]

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(train['total_zakat'],order=(1,1,1)) 
results=model.fit()

# %%
# predictions
predictions=results.predict(start,end,typ='levels').rename('ARIMA(1,1,1) Predictions')

# %%
test['total_zakat'].plot(legend=True)
predictions.plot(legend=True)

# %%
print("ARIMA")
print("MAE: ",mean_absolute_error(test['total_zakat'],predictions))
print("MSE: ",mean_squared_error(test['total_zakat'],predictions))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_zakat'],predictions)))
print("R2: ",r2_score(test['total_zakat'],predictions))
print("")
# Out:
# ARIMA
# MAE:  1534952.2800235508
# MSE:  2565215453476.6294
# RMSE:  1601628.9999486865
# R2:  -15.857917714440866

# %%
# Forecast into future
model=ARIMA(zakatguest['total_zakat'],order=(1,1,1))
results=model.fit()
fcast=results.predict(start=len(zakatguest),end=len(zakatguest)+36,typ='levels').rename('ARIMA(1,1,1) forecast')

# %%
zakatguest['total_zakat'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train['total_zakat'],order=(1,1,1),seasonal_order=(1,0,0,12))
results=model.fit()

# %%
predictions1=results.predict(start,end,typ='levels').rename('SARIMA Predictions')

# %%
test['total_zakat'].plot(legend=True,figsize=(8,5))
predictions1.plot(legend=True)

# %%
print("SARIMAX")
print("MAE: ",mean_absolute_error(test['total_zakat'],predictions1))
print("MSE: ",mean_squared_error(test['total_zakat'],predictions1))
print("RMSE: ", np.sqrt(mean_squared_error(test['total_zakat'],predictions1)))
print("R2: ",r2_score(test['total_zakat'],predictions1))
print("")
# Out:
# SARIMAX
# MAE:  997018.5177673518
# MSE:  1166982417726.1912
# RMSE:  1080269.6041850809
# R2:  -6.669099897852546

# %%
model=SARIMAX(zakatguest['total_zakat'],order=(1,1,1),seasonal_order=(1,0,0,12))
results=model.fit()
fcast=results.predict(start=len(zakatguest),end=len(zakatguest)+36,typ='levels').rename('SARIMA Forecast')

# %%
zakatguest['total_zakat'].plot(legend=True,figsize=(8,5))
fcast.plot(legend=True)

# %% [markdown]
# #### Machine Learning Approach

# %%
mlzakat = zakatguest.copy()
mlzakat.drop(['tanggal'], axis=1, inplace=True)
mlzakat.head()
# Out:
#    index  total_zakat
# 0      0     150000.0
# 1      1     100000.0
# 2      2    1070000.0
# 3      3    1000000.0
# 4      4    5000000.0

# %%
def LaggedFeatures(s,lag=2,fillna=True, dropna=False):
    if type(s) is pd.DataFrame:
        new_dict={}
        for col_name in s:
            new_dict[col_name]=s[col_name]
            # create lagged Series
            for l in range(1,lag+1):
                new_dict['%s_lag%d' %(col_name,l)]=s[col_name].shift(l)
        res=pd.DataFrame(new_dict,index=s.index)

    elif type(s) is pd.Series:
        the_range=range(lag+1)
        res=pd.concat([s.shift(i) for i in the_range],axis=1)
        res.columns=['lag_%d' %i for i in the_range]
    else:
        print ('Only works for DataFrame or Series')
        return None
    if dropna:
        res = res.dropna()
    else:
        res = res
    if fillna:
        return res.fillna(0)
    else:
        return res

# %%
lag2 = LaggedFeatures(mlzakat,lag=3,fillna=True, dropna=True)
lag2.shape
# Out:
# (64, 8)

# %%
train = lag2.iloc[:50]
test = lag2.iloc[50:]
train
# Out:
#     index  index_lag1  ...  total_zakat_lag2  total_zakat_lag3
# 3       3         2.0  ...          100000.0          150000.0
# 4       4         3.0  ...         1070000.0          100000.0
# 5       5         4.0  ...         1000000.0         1070000.0
# 6       6         5.0  ...         5000000.0         1000000.0
# 7       7         6.0  ...          200000.0         5000000.0
# 8       8         7.0  ...          120000.0          200000.0
# 9       9         8.0  ...         1150000.0          120000.0
# 10     10         9.0  ...          400000.0         1150000.0
# 11     11        10.0  ...          930000.0          400000.0
# 12     12        11.0  ...         5000000.0          930000.0
# 13     13        12.0  ...          260000.0         5000000.0
# 14     14        13.0  ...          185000.0          260000.0
# 15     15        14.0  ...          500000.0          185000.0
# 16     16        15.0  ...         1000000.0          500000.0
# ...

# %%
X_train = train.drop(['total_zakat'], axis=1)
X_test = test.drop(['total_zakat'], axis=1)

y_train = train['total_zakat']
y_test = test ['total_zakat']


X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
# call model
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

rf = RandomForestRegressor()
lr = LinearRegression()

#train
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np


y_pred_rf = rf.predict(X_test)
y_pred_lr = lr.predict(X_test)


print("Random Forest Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
print("MSE: ",mean_squared_error(y_test,y_pred_rf))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("R2: ",r2_score(y_test,y_pred_rf))
print("")

print("Linear Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
print("MSE: ",mean_squared_error(y_test,y_pred_lr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
print("R2: ",r2_score(y_test,y_pred_lr))
print("")
# Out:
# Random Forest Regression
# MAE:  340755.4335714286
# MSE:  183319506713.90823
# RMSE:  428158.27297146583
# R2:  -0.45270667852559066
#
# Linear Regression
# MAE:  513268.7618060951
# MSE:  326156117330.2132
# RMSE:  571100.7943701473
# R2:  -1.5846085797460279

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(18,6)) 

axs[0].plot(y_test,label='real values')
axs[0].plot(y_pred_rf,label='predicted values')
axs[0].set_title("Random Forest")
axs[0].legend()

axs[1].plot(y_test,label='real values')
axs[1].plot(y_pred_lr,label='predicted values')
axs[1].set_title("Linear Regression")
axs[1].legend()

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from pandas.tseries.offsets import DateOffset
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
zakatguest
# Out:
#             index  total_zakat
# tanggal
# 2021-01-05      0     150000.0
# 2021-01-06      1     100000.0
# 2021-01-07      2    1070000.0
# 2021-01-09      3    1000000.0
# 2021-01-18      4    5000000.0
# ...           ...          ...
# 2021-11-28     62     300000.0
# 2021-11-29     63     100000.0
# 2021-11-30     64     350000.0
# 2021-12-02     65    1175000.0
# 2021-12-03     66     213000.0
#
# [67 rows x 2 columns]

# %%
zakatguest = zakatguest.set_index('tanggal')

# %%
train_zakatguest = zakatguest[:len(zakatguest)-8]
test_zakatguest = zakatguest[len(zakatguest)-8:]

# %%
scaler = MinMaxScaler()
scaler.fit(train_zakatguest)
train = scaler.transform(train_zakatguest)
test = scaler.transform(test_zakatguest)

# %%
n_input = 40
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator,epochs=90, verbose= 0)
model.summary()

# %%
pred_list = []
batch = train[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=zakatgues[-n_input:].index, columns=['Prediction'])
df_test = pd.concat([zakatguest,df_predict], axis=1)

# %%
print("LSTM")
print("MAE: ",mean_absolute_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("MSE: ",mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("RMSE: ", np.sqrt(mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1])))
print("R2: ",r2_score(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("")

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test['total_zakat'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
